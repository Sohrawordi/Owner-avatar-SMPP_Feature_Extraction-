# %%
def raw_moment(d,m):
    #import statistics as sts

    s=0

        #p=sts.mean(d)
    for j in range(len(d)):
        #print(d[j],(d[j])**m)
        s=s+(d[j])**m

    return (s/len(d))













def moment(dataset):
    import pandas as pd
    #import statistics as sts
    from scipy import stats
    #import numpy as np
    #amino_acid="ACDEFGHIKLMNPQRSTWYVX"


    aaindex=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SMPP_Extended/Index.CSV")
    colls=[]
    for i in range(len(aaindex.index)):
        #print(aaindex['Index'][i])
        index=aaindex['Index'][i]
        for j in range (1,3):
            colls.extend([index+"_raw_moment_"+str(j)])

        for j in range (2,3):
            colls.extend([index+"_central_moment_"+str(j)])

    df=pd.DataFrame(columns=colls)




    for i in range(len(dataset.index)):
        #data_list=[]
        seq=dataset['Sequence'][i]
        row={}
       # print(seq)
        for index in range (len(aaindex.index)):
            data_list=[]
            for acid in seq:
                #print(acid,aaindex[acid][index])
                data_list.extend([aaindex[acid][index]])
            new_list=data_list
            #print(data_list)
            #new_list=np.divide(data_list,sum(data_list))
            #print(new_list)
            for m in range(1,3):
                row[aaindex['Index'][index]+"_raw_moment_"+str(m)]=raw_moment(new_list,m)



            for m in range(2,3):
                #print(aaindex['Index'][index]+"_central_moment_"+str(m))
                #print(stats.moment(new_list,moment=m))
                row[aaindex['Index'][index]+"_central_moment_"+str(m)]=stats.moment(new_list,moment=m)






        #df=df.append(row,ignore_index=True)
        df.loc[len(df)] =row


    return df

# %%
import pandas as pd
positive=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SMPP_Extended/Positive.csv")
#n=positive
#positive=positive.sample(frac=3, replace='True')
#positive=positive.reset_index(drop=True)
#positive.to_csv('Negative.csv',index=False)



df=moment(positive)

print(df)
df.to_csv('/content/drive/MyDrive/Colab Notebooks/SMPP_Extended/positive_numerical_moment_samples.csv',index=False)

# %%
Negative=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/SMPP_Extended/Negative.csv')
Negative=Negative.sample(frac=1/3)
Negative=Negative.reset_index(drop=True)
Negative.to_csv('/content/drive/MyDrive/Colab Notebooks/SMPP_Extended/Selected_negative.csv',index=False)
df=moment(Negative)
print(df)
df.to_csv('negative_numerical_moment_samples.csv',index=False)
